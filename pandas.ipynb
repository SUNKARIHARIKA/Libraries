# %%
#pandas is a library which is used for mainly data analysis and data manuplation
#pandas library mailnly works on tabular data
#the mainly used data structures of pandas are series and DataFrame
#series is similar to single column of data while dataframe is colection of both rows and columns

# %%
import pandas

# %%
print(pandas.__version__)
# Out:
# 2.2.3

# %%
#if we want to load or read data from excel----read_excel("file_location")
#if we want to load or read data from csv----read_csv("file_location)

# %%
import pandas as pd

# %%
#creating dataframe using dictionary
d1={"name":["harika","meghana","sitha"],"roll_no":[100,200,300],"cgpa":[9.0,9.6,9.7]}

# %%
d1
# Out:
# {'name': ['harika', 'meghana', 'sitha'],
#  'roll_no': [100, 200, 300],
#  'cgpa': [9.0, 9.6, 9.7]}

# %%
df1=pd.DataFrame(d1)

# %%
df1
# Out:
#       name  roll_no  cgpa
# 0   harika      100   9.0
# 1  meghana      200   9.6
# 2    sitha      300   9.7

# %%
#creating dataframe using list and tuple
l=[('abc',10,7.8),('def',8,8.9),('ghi',5,9.0)]
l
# Out:
# [('abc', 10, 7.8), ('def', 8, 8.9), ('ghi', 5, 9.0)]

# %%
df2=pd.DataFrame(l)
df2
# Out:
#      0   1    2
# 0  abc  10  7.8
# 1  def   8  8.9
# 2  ghi   5  9.0

# %%
d = pd.read_csv("C:\\Users\\sunka\\OneDrive\\Desktop\\Latest Covid-19 India Status.csv", encoding='utf-8')
df=pd.DataFrame(d)   #first the data will be stored in d and then we are creating dataframe

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df.head()  #default return first 5 rows
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
# 4                Bihar       855267       1      842952   12314           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.56         1.44    40100376

# %%
df.head(2)
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364

# %%
df.tail()   #default returns last 5 rows
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 31      Telengana       844432       8      840313    4111          0.00
# 32        Tripura       108493       1      107550     942          0.00
# 33  Uttar Pradesh      2145431      57     2121662   23712          0.00
# 34    Uttarakhand       452571       0      444803    7768          0.00
# 35    West Bengal      2126282     135     2104592   21555          0.01
#
#     Discharge Ratio  Death Ratio  Population
# 31            99.51         0.49    69599762
# 32            99.13         0.87     1646050
# 33            98.89         1.11     1158040
# 34            98.28         1.72    85002417
# 35            98.98         1.01    32199722

# %%
df.tail(10) #return last 10 rows
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 26     Puducherry       177547       0      175566    1981          0.00
# 27         Punjab       793644    1233      773073   19338          0.16
# 28      Rajasthan      1326465       2     1316727    9736          0.00
# 29         Sikkim        44927       4       44422     501          0.01
# 30     Tamil Nadu      3610655       5     3572569   38081          0.00
# 31      Telengana       844432       8      840313    4111          0.00
# 32        Tripura       108493       1      107550     942          0.00
# 33  Uttar Pradesh      2145431      57     2121662   23712          0.00
# 34    Uttarakhand       452571       0      444803    7768          0.00
# 35    West Bengal      2126282     135     2104592   21555          0.01
#
#     Discharge Ratio  Death Ratio  Population
# 26            98.88         1.12     2073074
# 27            97.41         2.44    34698876
# ...

# %%
df.describe()  #display all the statistical information related to the data
# Out:
#         Total Cases       Active    Discharged         Deaths  Active Ratio  \
# count  3.600000e+01    36.000000  3.600000e+01      36.000000     36.000000
# mean   1.249975e+06    50.333333  1.235146e+06   14778.527778      0.005000
# std    1.846038e+06   207.118048  1.820328e+06   27221.140636      0.026673
# min    1.076600e+04     0.000000  1.063700e+04       4.000000      0.000000
# 25%    1.065430e+05     0.000000  1.055395e+05    1124.250000      0.000000
# 50%    6.140910e+05     1.500000  6.076750e+05    6551.000000      0.000000
# 75%    1.331951e+06     9.000000  1.322329e+06   14325.750000      0.000000
# max    8.171048e+06  1233.000000  8.022276e+06  148558.000000      0.160000
#
#        Discharge Ratio  Death Ratio    Population
# count        36.000000    36.000000  3.600000e+01
# mean         98.897222     1.097778  3.971861e+07
# std           0.506854     0.494791  5.050913e+07
# min          97.410000     0.030000  6.600100e+04
# ...

# %%
df.shape  #display the number of rows and columns of the dataframe(consist of 9 columns and 36 rows)
# Out:
# (36, 9)

# %%
df[0:10:1]
# Out:
#                                   State/UTs  Total Cases  Active  Discharged  \
# 0                       Andaman and Nicobar        10766       0       10637
# 1                            Andhra Pradesh      2340676       0     2325943
# 2                         Arunachal Pradesh        67049       0       66753
# 3                                     Assam       746159       5      738119
# 4                                     Bihar       855267       1      842952
# 5                                Chandigarh       100693       0       99508
# 6                              Chhattisgarh      1187695       0     1173505
# 7  Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                     Delhi      2040910      14     2014230
# 9                                       Goa       263346       3      259329
#
#    Deaths  Active Ratio  Discharge Ratio  Death Ratio  Population
# ...

# %%
df[0:10:2]
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 4                Bihar       855267       1      842952   12314           0.0
# 6         Chhattisgarh      1187695       0     1173505   14190           0.0
# 8                Delhi      2040910      14     2014230   26666           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 2            99.56         0.44      658019
# 4            98.56         1.44    40100376
# 6            98.81         1.19    28900667
# 8            98.69         1.31      773997

# %%
#we can access the dataframe using the column name
df["State/UTs"]
# Out:
# 0                          Andaman and Nicobar
# 1                               Andhra Pradesh
# 2                            Arunachal Pradesh
# 3                                        Assam
# 4                                        Bihar
# 5                                   Chandigarh
# 6                                 Chhattisgarh
# 7     Dadra and Nagar Haveli and Daman and Diu
# 8                                        Delhi
# 9                                          Goa
# 10                                     Gujarat
# 11                                     Haryana
# 12                            Himachal Pradesh
# 13                           Jammu and Kashmir
# 14                                   Jharkhand
# 15                                   Karnataka
# 16                                      Kerala
# 17                                      Ladakh
# 18                                 Lakshadweep
# 19                              Madhya Pradesh
# ...

# %%
df[["State/UTs","Total Cases"]]
# Out:
#                                    State/UTs  Total Cases
# 0                        Andaman and Nicobar        10766
# 1                             Andhra Pradesh      2340676
# 2                          Arunachal Pradesh        67049
# 3                                      Assam       746159
# 4                                      Bihar       855267
# 5                                 Chandigarh       100693
# 6                               Chhattisgarh      1187695
# 7   Dadra and Nagar Haveli and Daman and Diu        11592
# 8                                      Delhi      2040910
# 9                                        Goa       263346
# 10                                   Gujarat      1291383
# 11                                   Haryana      1078903
# 12                          Himachal Pradesh       322905
# 13                         Jammu and Kashmir       482023
# 14                                 Jharkhand       443826
# ...

# %%
df[["State/UTs","Total Cases"]][0:10:2]
# Out:
#              State/UTs  Total Cases
# 0  Andaman and Nicobar        10766
# 2    Arunachal Pradesh        67049
# 4                Bihar       855267
# 6         Chhattisgarh      1187695
# 8                Delhi      2040910

# %%
#iterrows--to access individual rows in dataframe
for record in df.iterrows():
    print(record)
# Out:
# (0, State/UTs          Andaman and Nicobar
# Total Cases                      10766
# Active                               0
# Discharged                       10637
# Deaths                             129
# Active Ratio                       0.0
# Discharge Ratio                   98.8
# Death Ratio                        1.2
# Population                   100896618
# Name: 0, dtype: object)
# (1, State/UTs          Andhra Pradesh
# Total Cases               2340676
# Active                          0
# Discharged                2325943
# Deaths                      14733
# Active Ratio                  0.0
# Discharge Ratio             99.37
# Death Ratio                  0.63
# Population              128500364
# Name: 1, dtype: object)
# (2, State/UTs          Arunachal Pradesh
# Total Cases                    67049
# Active                             0
# Discharged                     66753
# Deaths                           296
# Active Ratio                     0.0
# ...

# %%
#LOC[](stop index included)

# %%
df.loc[1]  #display the first row
# Out:
# State/UTs          Andhra Pradesh
# Total Cases               2340676
# Active                          0
# Discharged                2325943
# Deaths                      14733
# Active Ratio                  0.0
# Discharge Ratio             99.37
# Death Ratio                  0.63
# Population              128500364
# Name: 1, dtype: object

# %%
df.loc[19,["State/UTs","Total Cases"]]  #displays the 19th row state name and cases
# Out:
# State/UTs      Madhya Pradesh
# Total Cases           1056351
# Name: 19, dtype: object

# %%
df.loc[0:5]  #includes the stop index also
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
# 4                Bihar       855267       1      842952   12314           0.0
# 5           Chandigarh       100693       0       99508    1185           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.56         1.44    40100376
# 5            98.82         1.18    30501026

# %%
#if we are using iloc then stop index will not be included
df.iloc[0:5]
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
# 4                Bihar       855267       1      842952   12314           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.56         1.44    40100376

# %%
df.loc[0:5,["State/UTs","Discharged"]]
# Out:
#              State/UTs  Discharged
# 0  Andaman and Nicobar       10637
# 1       Andhra Pradesh     2325943
# 2    Arunachal Pradesh       66753
# 3                Assam      738119
# 4                Bihar      842952
# 5           Chandigarh       99508

# %%
df.loc[0:4,"State/UTs":"Discharge Ratio"]   #displays first 4 rows from states coulumn to discharged ratio
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
# 4                Bihar       855267       1      842952   12314           0.0
#
#    Discharge Ratio
# 0            98.80
# 1            99.37
# 2            99.56
# 3            98.92
# 4            98.56

# %%
#understanding loc
'''
data_frame.loc[row_number]
data_frame.loc[row_number,[coumn_name---]]
data_frame.loc[start:stop]
data_frame.loc[start:stop,"column_name"]
data_frame.loc[start:stop,[coumn1,column2---]]
data_frame.loc[start:stop,"column1":"coulumn2"]'''
# Out:
# '\ndata_frame.loc[row_number]\ndata_frame.loc[row_number,[coumn_name---]]\ndata_frame.loc[start:stop]\ndata_frame.loc[start:stop,"column_name"]\ndata_frame.loc[start:stop,[coumn1,column2---]]\ndata_frame.loc[start:stop,"column1":"coulumn2"]'

# %%
#iloc---

# %%
df.iloc[0:4]  #end index is not included
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492

# %%
df.iloc[2,0]
# Out:
# 'Arunachal Pradesh'

# %%
#in iloc columns are accessed by index values where as in loc coulmns are accessed by its name

# %%
df.iloc[0:5,0:3]  #displays the 0-4 rows and 0-2 columns
# Out:
#              State/UTs  Total Cases  Active
# 0  Andaman and Nicobar        10766       0
# 1       Andhra Pradesh      2340676       0
# 2    Arunachal Pradesh        67049       0
# 3                Assam       746159       5
# 4                Bihar       855267       1

# %%
df.iloc[0:4,2]
# Out:
# 0    0
# 1    0
# 2    0
# 3    5
# Name: Active, dtype: int64

# %%
df.iloc[[1,2,3]]  #3 rows will be displayed
# Out:
#            State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1     Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2  Arunachal Pradesh        67049       0       66753     296           0.0
# 3              Assam       746159       5      738119    8035           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492

# %%
df.iloc[[1,5,6,2]]  #print 1st 5th 6th 2nd rows
# Out:
#            State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1     Andhra Pradesh      2340676       0     2325943   14733           0.0
# 5         Chandigarh       100693       0       99508    1185           0.0
# 6       Chhattisgarh      1187695       0     1173505   14190           0.0
# 2  Arunachal Pradesh        67049       0       66753     296           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 1            99.37         0.63   128500364
# 5            98.82         1.18    30501026
# 6            98.81         1.19    28900667
# 2            99.56         0.44      658019

# %%
df.iloc[:,[1,2,5]]
# Out:
#     Total Cases  Active  Active Ratio
# 0         10766       0          0.00
# 1       2340676       0          0.00
# 2         67049       0          0.00
# 3        746159       5          0.00
# 4        855267       1          0.00
# 5        100693       0          0.00
# 6       1187695       0          0.00
# 7         11592       0          0.00
# 8       2040910      14          0.00
# 9        263346       3          0.00
# 10      1291383       5          0.00
# 11      1078903      27          0.00
# 12       322905       4          0.00
# 13       482023       0          0.00
# 14       443826       1          0.00
# 15      4088769      12          0.00
# 16      6907241      18          0.00
# 17        29602       0          0.00
# 18        11415       0          0.00
# 19      1056351       0          0.00
# 20      8171048     214          0.00
# 21       140034       0          0.00
# 22        96983       3          0.00
# 23       239560       1          0.00
# ...

# %%
df.iloc[0:5,[1,2,5]]
# Out:
#    Total Cases  Active  Active Ratio
# 0        10766       0           0.0
# 1      2340676       0           0.0
# 2        67049       0           0.0
# 3       746159       5           0.0
# 4       855267       1           0.0

# %%
#understanding iloc---
'''
data_frame.iloc[row_number,column_number]
data_frame.iloc[row_start:row_stop,col_start:col_stop]
data_frame.iloc[start:stop,column_name]
data_frame.iloc[[row1,row2,--]]
data_frame.iloc[:,[column1,column2,--]]
data_frame.iloc[start:stop,[coulumn1,column2--]]'''
# Out:
# '\ndata_frame.iloc[row_number,column_number]\ndata_frame.iloc[row_start:row_stop,col_start:col_stop]\ndata_frame.iloc[start:stop,column_name]\ndata_frame.iloc[[row1,row2,--]]\ndata_frame.iloc[:,[column1,column2,--]]\ndata_frame.iloc[start:stop,[coulumn1,column2--]]'

# %%
#sorting the dataframe

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df.sort_values("Total Cases")  #sorts the dataframe based on ascending order of total cases
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 18                               Lakshadweep        11415       0       11363
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 17                                    Ladakh        29602       0       29371
# 24                                  Nagaland        36033       0       35251
# 29                                    Sikkim        44927       4       44422
# 2                          Arunachal Pradesh        67049       0       66753
# 22                                 Meghalaya        96983       3       95352
# 5                                 Chandigarh       100693       0       99508
# 32                                   Tripura       108493       1      107550
# 21                                   Manipur       140034       0      137885
# ...

# %%
df.sort_values("Total Cases",ascending=False)  #sortes the dataframe based on total cases in descending order
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 20                               Maharashtra      8171048     214     8022276
# 16                                    Kerala      6907241      18     6835181
# 15                                 Karnataka      4088769      12     4048399
# 30                                Tamil Nadu      3610655       5     3572569
# 1                             Andhra Pradesh      2340676       0     2325943
# 33                             Uttar Pradesh      2145431      57     2121662
# 35                               West Bengal      2126282     135     2104592
# 8                                      Delhi      2040910      14     2014230
# 25                                    Odisha      1348409      59     1339135
# 28                                 Rajasthan      1326465       2     1316727
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df.sort_values(["State/UTs","Total Cases"])  #priority will be given to first coulumn1
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
#sorting syntax
'''
data_frame.sort_values("coulumn_name")
data_frame.sort_values("coulumn_name",ascending=False)
data_frame.sort_values(["column1",column2])'''
# Out:
# '\ndata_frame.sort_values("coulumn_name")\ndata_frame.sort_values("coulumn_name",ascending=False)\ndata_frame.sort_values(["column1",column2])'

# %%
#manuplating dataframe

# %%
#adding a coulumn_name
df["Total"]=0

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df["Total"]=df["Total Cases"]+df["Active"]

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
#deleting a coulmn

# %%
df["status"]="haelaty/unhealthy"

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df.drop(columns="status")  #the status coulumn will be deleted temprarily
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df  #again it will shows the coulmn
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df.drop(columns="status",inplace=True) if we keep inplace the changes will be applied to dataframe permenantly
# Out:
#   Cell In[61], line 1
#     df.drop(columns="status",inplace=True) if we keep inplace the changes will be applied to dataframe permenantly
#     ^
# SyntaxError: expected 'else' after 'if' expression

# %%
df #now the dataframe is deleted
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
#remove duplicates

# %%
#to check whether the dataframe consist of duplicates or not
df.duplicated()   #no repeatation is present
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# dtype: bool

# %%
df.drop_duplicates(inplace=True)  #delete the duplicate rows

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
#handling missing data

# %%
df.dropna(inplace=True)   #This removes all rows that contain at least one NaN value.

# %%
#fill with default values
df.fillna(4)  #if there is any missing value the value will be filled with  4
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
#simple consdition
df.loc[df["Total Cases"]>1000000]
# Out:
#          State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1   Andhra Pradesh      2340676       0     2325943   14733          0.00
# 6     Chhattisgarh      1187695       0     1173505   14190          0.00
# 8            Delhi      2040910      14     2014230   26666          0.00
# 10         Gujarat      1291383       5     1280299   11079          0.00
# 11         Haryana      1078903      27     1068121   10755          0.00
# 15       Karnataka      4088769      12     4048399   40358          0.00
# 16          Kerala      6907241      18     6835181   72042          0.00
# 19  Madhya Pradesh      1056351       0     1045565   10786          0.00
# 20     Maharashtra      8171048     214     8022276  148558          0.00
# 25          Odisha      1348409      59     1339135    9215          0.00
# 28       Rajasthan      1326465       2     1316727    9736          0.00
# 30      Tamil Nadu      3610655       5     3572569   38081          0.00
# ...

# %%
#compound condition
df.loc[(df["Total Cases"]>60000) & (df["Total Cases"]<100000)]
# Out:
#             State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 2   Arunachal Pradesh        67049       0       66753     296           0.0
# 22          Meghalaya        96983       3       95352    1628           0.0
#
#     Discharge Ratio  Death Ratio  Population  Total             status
# 2             99.56         0.44      658019  67049  haelaty/unhealthy
# 22            98.32         1.68    79502477  96986  haelaty/unhealthy

# %%
#string condition
df.loc[df["State/UTs"].str.contains("n")]
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 5                                 Chandigarh       100693       0       99508
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 11                                   Haryana      1078903      27     1068121
# 13                         Jammu and Kashmir       482023       0      477231
# 14                                 Jharkhand       443826       1      438491
# 15                                 Karnataka      4088769      12     4048399
# 21                                   Manipur       140034       0      137885
# 24                                  Nagaland        36033       0       35251
# ...

# %%
df.loc[df["State/UTs"].str.startswith("A")]
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
#
#    Discharge Ratio  Death Ratio  Population    Total             status
# 0            98.80         1.20   100896618    10766  haelaty/unhealthy
# 1            99.37         0.63   128500364  2340676  haelaty/unhealthy
# 2            99.56         0.44      658019    67049  haelaty/unhealthy
# 3            98.92         1.08      290492   746164  haelaty/unhealthy

# %%
df.loc[df["State/UTs"].str.endswith("b")]
# Out:
#    State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 27    Punjab       793644    1233      773073   19338          0.16
#
#     Discharge Ratio  Death Ratio  Population   Total             status
# 27            97.41         2.44    34698876  794877  haelaty/unhealthy
